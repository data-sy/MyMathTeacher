# %%
import json

# %%
# json 파일은 sample_data의 labeled_data
# 파일 구조 내용은 출력용으로 json타이핑.txt
# 실제 세부 내역에 대한 이해는 가이드라인.pdf 3page~

# %%
file_ox = './data/labeled_data/1_문항정오답표_rule_20210210163612.json'
file_itemIRT = './data/labeled_data/2_문항IRT_rule_20210210164012.json'
file_stuIRT = './data/labeled_data/3_응시자IRT_rule_20210210164059.json'

# %% [markdown]
# ### 문항정오답표

# %%
# 문항정오답표
with open(file_ox, 'r') as f:
    json_data = json.load(f)
    print(json.dumps(json_data, indent = 4))
# Out:
# {
#     "description": "Rule Auto Generated By SDQ for AI",
#     "type": "object",
#     "title": "Diagnosis Rule",
#     "properties": {
#         "answerCode": {
#             "type": "string"
#         },
#         "learnerID": {
#             "type": "string"
#         },
#         "testID": {
#             "type": "string"
#         },
#         "learnerProfile": {
#             "type": "string"
#         },
#         "Timestamp": {
#             "type": "string"
#         },
#         "assessmentItemID": {
#             "type": "string"
#         }
#     }
# }

# %%
'''
{
	"learnerID" : "2", ----------------------------------> 학습자 ID
	"learnerProfile" : "M, elementary, 1", --------------> 학습자 정보 : 성별, 학교급, 학년
	"testID" : "0101",                     --------------> 평가 ID
	"assessmentItemID" : "202045",         --------------> 평가 문항 ID
	"answerCode" : "0",                    --------------> 정답 1 오답 0
	"timeStamp" : "2020-11-16 18:14:41.976979"-----------> 데이터 생성,수정 시간
}
'''
# Out:
# '\n{\n\t"learnerID" : "2", ----------------------------------> 학습자 ID\n\t"learnerProfile" : "M, elementary, 1", --------------> 학습자 정보 : 성별, 학교급, 학년\n\t"testID" : "0101",                     --------------> 평가 ID\n\t"assessmentItemID" : "202045",         --------------> 평가 문항 ID\n\t"answerCode" : "0",                    --------------> 정답 1 오답 0\n\t"timeStamp" : "2020-11-16 18:14:41.976979"-----------> 데이터 생성,수정 시간\n}\n'

# %% [markdown]
# ### 문항IRT

# %%
# 문항IRT
with open(file_itemIRT, 'r') as f:
    json_data = json.load(f)
    print(json.dumps(json_data, indent = 4))
# Out:
# {
#     "description": "Rule Auto Generated By SDQ for AI",
#     "type": "object",
#     "title": "Diagnosis Rule",
#     "properties": {
#         "difficultyLevel": {
#             "type": "number"
#         },
#         "discriminationLevel": {
#             "type": "number"
#         },
#         "testID": {
#             "type": "string"
#         },
#         "knowledgeTag": {
#             "type": "string"
#         },
#         "Timestamp": {
#             "type": "string"
#         },
#         "assessmentItemID": {
#             "type": "string"
#         },
#         "guessLevel": {
#             "type": "number"
#         }
#     }
# }

# %%
'''
{
	"testID" : "0101",               --------------> 평가 ID
	"assessmentItemID" : "202045",   --------------> 평가 문항 ID
	"difficultyLevel" : -1.824483892,--------------> 문항 난이도
	"discriminationLevel" : 0.974675832,-----------> 문항 변별도
	"guessLevel" : "0.0000112345",   --------------> 문항 추측도
    신뢰도는? reliabilityLevel
	"timeStamp" : "2020-11-16 18:14:41.976979"-----> 데이터 생성수정 시간
	"KnowledgeTag" : "중등-중1-1학-01-01-02"-------> 개념적 지식 태그
}
'''
# Out:
# '\n{\n\t"testID" : "0101",               --------------> 평가 ID\n\t"assessmentItemID" : "202045",   --------------> 평가 문항 ID\n\t"difficultyLevel" : -1.824483892,--------------> 문항 난이도\n\t"discriminationLevel" : 0.974675832,-----------> 문항 변별도\n\t"guessLevel" : "0.0000112345",   --------------> 문항 추측도\n    신뢰도는? reliabilityLevel\n\t"timeStamp" : "2020-11-16 18:14:41.976979"-----> 데이터 생성수정 시간\n\t"KnowledgeTag" : "중등-중1-1학-01-01-02"-------> 개념적 지식 태그\n}\n'

# %% [markdown]
# ### 응시자IRT

# %%
# 응시자IRT
with open(file_itemIRT, 'r') as f:
    json_data = json.load(f)
    print(json.dumps(json_data, indent = 4))
# Out:
# {
#     "description": "Rule Auto Generated By SDQ for AI",
#     "type": "object",
#     "title": "Diagnosis Rule",
#     "properties": {
#         "difficultyLevel": {
#             "type": "number"
#         },
#         "discriminationLevel": {
#             "type": "number"
#         },
#         "testID": {
#             "type": "string"
#         },
#         "knowledgeTag": {
#             "type": "string"
#         },
#         "Timestamp": {
#             "type": "string"
#         },
#         "assessmentItemID": {
#             "type": "string"
#         },
#         "guessLevel": {
#             "type": "number"
#         }
#     }
# }

# %%
'''
{
	"learnerID" : "2",                  ----------> 학습자 ID
	"learnerProfile" : "M, elementary, 1",--------> 학습자 정보 : 성별, 학교급, 학년
	"testID" : "0101",                  ----------> 평가 ID
	"theta" : -3.824483892,             ----------> 학습자의 이해력 수준
	"realScore" : 4.483579245,          ----------> 학습자의 진점수
	"timeStamp" : "2020-11-16 18:14:41.976979"----> 데이터 갱신 시간
}
'''
# Out:
# '\n{\n\t"learnerID" : "2",                  ----------> 학습자 ID\n\t"learnerProfile" : "M, elementary, 1",--------> 학습자 정보 : 성별, 학교급, 학년\n\t"testID" : "0101",                  ----------> 평가 ID\n\t"theta" : -3.824483892,             ----------> 학습자의 이해력 수준\n\t"realScore" : 4.483579245,          ----------> 학습자의 진점수\n\t"timeStamp" : "2020-11-16 18:14:41.976979"----> 데이터 갱신 시간\n}\n'
