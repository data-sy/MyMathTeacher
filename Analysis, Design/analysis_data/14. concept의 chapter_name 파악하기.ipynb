# %%
import json

json_path = './data/concepts_sorted.json'
with open(json_path, 'r', encoding='utf-8') as j :
    concepts_sorted = json.load(j)

# %%
for concept in concepts_sorted:
    print(concept["chapter"]["name"])
# Out:
# 9까지의 수 > 몇일까요 (1)
# 9까지의 수 > 몇일까요 (2)
# 9까지의 수 > 몇째일까요
# 9까지의 수 > 수의 순서를 알아볼까요
# 9까지의 수 > 1만큼 더 큰 수와 1만큼 더 작은 수는 무엇일까요
# 9까지의 수 > 1만큼 더 큰 수와 1만큼 더 작은 수는 무엇일까요
# 9까지의 수 > 어느 수가 더 클까요
# 여러 가지 모양 > 여러 가지 모양을 찾아볼까요
# 여러 가지 모양 > 여러 가지 모양을 알아볼까요
# 여러 가지 모양 > 여러 가지 모양을 알아볼까요
# 여러 가지 모양 > 여러 가지 모양을 알아볼까요
# 여러 가지 모양 > 여러 가지 모양을 알아볼까요
# 여러 가지 모양 > 여러 가지 모양을 알아볼까요
# 덧셈과 뺄셈 > 모으기와 가르기를 해 볼까요 (1)
# 덧셈과 뺄셈 > 더하기는 어떻게 나타낼까요
# 덧셈과 뺄셈 > 덧셈을 해 볼까요 (1)
# 덧셈과 뺄셈 > 덧셈을 해 볼까요 (2)
# 덧셈과 뺄셈 > 빼기는 어떻게 나타낼까요
# 덧셈과 뺄셈 > 뺄셈을 해 볼까요 (1)
# 덧셈과 뺄셈 > 뺄셈을 해 볼까요 (2)
# 덧셈과 뺄셈 > 0을 더하거나 빼면 어떻게 될까요
# 덧셈과 뺄셈 > 0을 더하거나 빼면 어떻게 될까요
# 덧셈과 뺄셈 > 덧셈과 뺄셈을 해 볼까요
# 비교하기 > 어느 것이 더 길까요
# 비교하기 > 어느 것에 더 많이 담을 수 있을까요
# 50까지의 수 > 9다음 수는 무엇일까요
# 50까지의 수 > 십몇을 알아볼까요
# 50까지의 수 > 10개씩 묶어 세어 볼까요
# 50까지의 수 > 50까지의 수를 세어 볼까요
# 50까지의 수 > 수의 순서를 알아볼까요
# 50까지의 수 > 어느 수가 더 클까요
# 100까지의 수 > 60, 70, 80, 90을 알아볼까요
# 100까지의 수 > 60, 70, 80, 90을 알아볼까요
# 100까지의 수 > 99까지의 수를 알아볼까요
# 100까지의 수 > 수의 순서를 알아볼까요
# 100까지의 수 > 어느 수가 더 클까요
# ...

# %%
import numpy as np
import pandas as pd

df = pd.json_normalize(concepts_sorted)

# %%
df
# Out:
#         id              name   semester  \
# 0     5814        1부터 5까지의 수  초등-초1-1학기
# 1     5485                여섯  초등-초1-1학기
# 2     7581                첫째  초등-초1-1학기
# 3     5834             수의 순서  초등-초1-1학기
# 4     5835     1 큰 수와 1 작은 수  초등-초1-1학기
# ...    ...               ...        ...
# 1626  3351            구의 방정식   고등-기하-전체
# 1627  3200   좌표축에 접하는 구의 방정식   고등-기하-전체
# 1628  3202        두 구의 위치 관계   고등-기하-전체
# 1629  3203  구와 좌표평면의 교선의 방정식   고등-기하-전체
# 1630  3352       구의 방정식의 일반형   고등-기하-전체
#
#                                             description chapter.id  \
# 0                                1부터 5까지의 수를 읽고 셀 수 있다.          1
# 1                                          다섯에 하나를 더한 수          3
# 2                                  차례를 매길 때, 맨 처음에 오는 수          5
# 3     1부터 9까지의 수 1, 2, 3, 4, 5, 6, 7, 8, 9를 순서대로 나타낼...          6
# 4      수를 순서대로 썼을 때 바로 앞의 수가 1 작은 수, 바로 뒤의 수가 1 큰 수입니다.          7
# ...                                                 ...        ...
# ...

# %%
df_elem0101 = df[df["semester"]=="초등-초1-1학기"]
df_elem0101
# Out:
#       id                          name   semester  \
# 0   5814                    1부터 5까지의 수  초등-초1-1학기
# 1   5485                            여섯  초등-초1-1학기
# 2   7581                            첫째  초등-초1-1학기
# 3   5834                         수의 순서  초등-초1-1학기
# 4   5835                 1 큰 수와 1 작은 수  초등-초1-1학기
# 5   7593                             0  초등-초1-1학기
# 6   5836                  두 수의 크기 비교하기  초등-초1-1학기
# 7   5844                 여러 가지 모양 찾아보기  초등-초1-1학기
# 8   5845                 여러 가지 모양 알아보기  초등-초1-1학기
# 9   5846                여러 가지 모양으로 만들기  초등-초1-1학기
# 10  5848                 여러 가지 모양 알아보기  초등-초1-1학기
# 11  6307                 여러 가지 모양 알아보기  초등-초1-1학기
# 12  6308                여러 가지 모양 만들어보기  초등-초1-1학기
# 13  6409                      모으기와 가르기  초등-초1-1학기
# 14  7595   '+'와 '=' 기호를 사용하여 덧셈을 쓰고 읽기  초등-초1-1학기
# 15  7596             그림 그리기를 이용하여 덧셈하기  초등-초1-1학기
# 16  7597              수 모으기를 이용하여 덧셈하기  초등-초1-1학기
# 17  7598  '-'와 '=' 기호를 사용하여 뺄셈식을 쓰고 읽기  초등-초1-1학기
# ...

# %%
df_elem0602 = df[df["semester"]=="초등-초6-2학기"]
df_elem0602
# Out:
#         id                                           name   semester  \
# 473   9931             분자끼리 나누어떨어지는 분모가 같은 $(분수)\div(분수)$  초등-초6-2학기
# 474    705          분자끼리 나누어떨어지지 않는 분모가 같은 $(분수)\div(분수)$  초등-초6-2학기
# 475    706                          분모가 다른 $(분수)\div(분수)$  초등-초6-2학기
# 476    707                                $(자연수)\div(분수)$  초등-초6-2학기
# 477    708      $(분수)\div(분수)$를 $(분수)\times(분수)$로 나타내는 방법  초등-초6-2학기
# 478    709                                 $(분수)\div(분수)$  초등-초6-2학기
# 479    710                                 $(소수)\div(소수)$  초등-초6-2학기
# 480    711                         자릿수가 같은 $(소수)\div(소수)$  초등-초6-2학기
# 481    712                         자릿수가 다른 $(소수)\div(소수)$  초등-초6-2학기
# 482    713                                $(자연수)\div(소수)$  초등-초6-2학기
# 483    714                                  몫을 반올림하여 나타내기  초등-초6-2학기
# 484    770                                    나누어 주고 남는 양  초등-초6-2학기
# 485   1422  쌓기나무로 쌓은 모양과 위에서 본 모양을 보고 쌓은 모양과 쌓기나무의 개수 구하기  초등-초6-2학기
# ...

# %% [markdown]
# - 프론트에서 챕터 네임 1>2>3 중 1>2까지만 단계로 사용하기
# - 프론트에서 선택한 것을 String str으로 받아서 sql에서 'str%'로 사용하면 돼
# - 그러면 해당 중단원의 문항들 나올 수 있어
